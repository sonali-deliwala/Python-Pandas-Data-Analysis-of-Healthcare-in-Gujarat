# %%
import pandas
path_to_file = "/Users/ssd/Downloads/final_data.csv"
all_data = pandas.read_csv(path_to_file, encoding = 'utf-8')
all_data
# Out:
#         Districts Total population Scheduled Caste  Decimal Caste  \
# 0       Bhavnagar        2,880,365         157,034       0.054519
# 1           Kheda        2,299,885         115,631       0.050277
# 2    Sabar Kantha        2,428,589         187,685       0.077282
# 3    Banas Kantha        3,120,506          327460       0.104938
# 4    Panch Mahals        2,390,776         100,446       0.042014
# 5        Jamnagar        2,160,119          173895       0.080503
# 6          Rajkot        3,804,558         290,169       0.076269
# 7        Mahesana        2,035,064         162,288       0.079746
# 8       The Dangs          228,291             992       0.004345
# 9       Porbandar           585449           51830       0.088530
# 10        Kachchh          2092371          258859       0.123716
# 11          Surat          6081322          158115       0.026000
# 12        Narmada           590297            8733       0.014794
# ...

# %%
all_data["Percentage Tribe Literate"]
# Out:
# 0     18.331504
# 1     54.231952
# 2     52.178340
# 3     38.211188
# 4     48.365863
# 5     45.933766
# 6     46.829329
# 7     66.279813
# 8     61.024283
# 9     46.475957
# 10    43.363051
# 11    59.303438
# 12    59.485201
# 13    57.800742
# 14    56.928974
# 15    56.429262
# 16    36.356187
# 17    58.001954
# 18    66.608302
# 19    36.190743
# 20    69.490222
# 21    57.894270
# 22    58.458794
# 23    57.184439
# 24    45.922040
# 25    42.490369
# Name: Percentage Tribe Literate, dtype: float64

# %%
import statsmodels.api as sm # import statsmodels 
X = all_data["Literacy rate "]
y = all_data["Percent total HIV positive population"]
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       OLS Regression Results
# ...
# Dep. Variable:     Percent total HIV positive population   R-squared:                       0.058
# Model:                                               OLS   Adj. R-squared:                  0.018
# Method:                                    Least Squares   F-statistic:                     1.465
# Date:                                   Sat, 14 Dec 2019   Prob (F-statistic):              0.238
# Time:                                           15:19:25   Log-Likelihood:                -40.195
# No. Observations:                                     26   AIC:                             84.39
# Df Residuals:                                         24   BIC:                             86.91
# Df Model:                                              1
# Covariance Type:                               nonrobust
# ...

# %%
import statsmodels.api as sm # import statsmodels 
X = all_data["Literacy rate "]
y = all_data["Percent combined private and public C-sections"]
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                           OLS Regression Results
# ...
# Dep. Variable:     Percent combined private and public C-sections   R-squared:                       0.405
# Model:                                                        OLS   Adj. R-squared:                  0.381
# Method:                                             Least Squares   F-statistic:                     16.37
# Date:                                            Sun, 15 Dec 2019   Prob (F-statistic):           0.000469
# Time:                                                    00:05:44   Log-Likelihood:                -86.437
# No. Observations:                                              26   AIC:                             176.9
# Df Residuals:                                                  24   BIC:                             179.4
# Df Model:                                                       1
# ...

# %%
import seaborn as sns

sns.regplot(x = all_data['Literacy rate '], y = all_data['Percent total HIV positive population'])

# %%
import seaborn as sns

sns.regplot(x = all_data['Literacy rate '], y = all_data['Percent combined private and public C-sections'])

# %%
import pandas
path_to_file = "/Users/ssd/Downloads/final_data.csv"
all_data = pandas.read_csv(path_to_file, encoding = 'utf-8')

import seaborn as sns

sns.regplot(x = all_data['Percentage Rural'], y = all_data['Percent combined private and public C-sections'])

# %%
import seaborn as sns

sns.regplot(x = all_data['Percentage Rural'], y = all_data['Percent  C-sections at public facilities'])

# %%
sns.regplot(x = all_data['Literacy rate '], y = all_data['Percent  C-sections at public facilities'])
